# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruchiiika/dataScience/blob/main/first2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data= {'A':[1,2,3,np.nan],'B':[4,5,6,7],'C':[np.nan,8,9,0]}

# %%
data
# Out:
# {'A': [1, 2, 3, nan], 'B': [4, 5, 6, 7], 'C': [nan, 8, 9, 0]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C
# 0  1.0  4  NaN
# 1  2.0  5  8.0
# 2  3.0  6  9.0
# 3  NaN  7  0.0

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       4 non-null      int64
#  2   C       3 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#          A         B         C
# count  3.0  4.000000  3.000000
# mean   2.0  5.500000  5.666667
# std    1.0  1.290994  4.932883
# min    1.0  4.000000  0.000000
# 25%    1.5  4.750000  4.000000
# 50%    2.0  5.500000  8.000000
# 75%    2.5  6.250000  8.500000
# max    3.0  7.000000  9.000000

# %%
df.tail()
# Out:
#      A  B    C
# 0  1.0  4  NaN
# 1  2.0  5  8.0
# 2  3.0  6  9.0
# 3  NaN  7  0.0

# %%
df.head()
# Out:
#      A  B    C
# 0  1.0  4  NaN
# 1  2.0  5  8.0
# 2  3.0  6  9.0
# 3  NaN  7  0.0

# %%
df1=df.copy()

# %%
df1
# Out:
#      A  B    C
# 0  1.0  4  NaN
# 1  2.0  5  8.0
# 2  3.0  6  9.0
# 3  NaN  7  0.0

# %%
df1.dropna()
# Out:
#      A  B    C
# 1  2.0  5  8.0
# 2  3.0  6  9.0

# %%
df.dtypes
# Out:
# A    float64
# B      int64
# C    float64
# dtype: object

# %%
df2=df1.copy()

# %%
df2
# Out:
#      A  B    C
# 0  1.0  4  NaN
# 1  2.0  5  8.0
# 2  3.0  6  9.0
# 3  NaN  7  0.0

# %%
df2.dropna(axis=1)
# Out:
#    B
# 0  4
# 1  5
# 2  6
# 3  7

# %%
df['A']=pd.to_numeric(df['A'],errors='coerce')

# %%
df.dtypes
# Out:
# A    float64
# B      int64
# C    float64
# dtype: object
